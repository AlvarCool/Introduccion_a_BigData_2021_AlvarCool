# %%
import pandas as pd
data = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#         cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# 0          2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1          2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2          2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3          2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4          2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# ...               ...         ...         ...                        ...
# 8405074    2020/10/22         NaN         NaN              Probable Case
# 8405075    2020/10/25         NaN         NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN         NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN         NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN         NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# 0           Male  10 - 19 Years           Black, Non-Hispanic       No
# 1           Male  10 - 19 Years           Black, Non-Hispanic       No
# 2           Male  10 - 19 Years           Black, Non-Hispanic       No
# 3           Male  10 - 19 Years           Black, Non-Hispanic  Missing
# 4           Male  10 - 19 Years           Black, Non-Hispanic       No
# ...          ...            ...                           ...      ...
# 8405074  Missing  30 - 39 Years                       Unknown       No
# 8405075  Missing  30 - 39 Years                       Unknown  Missing
# 8405076  Missing  30 - 39 Years                       Unknown  Missing
# 8405077  Missing  30 - 39 Years                       Unknown  Missing
# 8405078  Missing  30 - 39 Years                       Unknown       No
#
#           icu_yn death_yn medcond_yn
# 0        Unknown       No         No
# 1             No       No         No
# 2             No       No         No
# 3        Missing       No    Missing
# 4             No       No        Yes
# ...          ...      ...        ...
# 8405074  Unknown       No    Missing
# 8405075  Missing  Missing    Missing
# 8405076  Missing  Missing    Missing
# 8405077  Missing  Missing    Missing
# 8405078  Unknown       No    Missing
#
# [8405079 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405079 entries, 0 to 8405078
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   cdc_report_dt                  object
#  1   pos_spec_dt                    object
#  2   onset_dt                       object
#  3   current_status                 object
#  4   sex                            object
#  5   age_group                      object
#  6   Race and ethnicity (combined)  object
#  7   hosp_yn                        object
#  8   icu_yn                         object
#  9   death_yn                       object
#  10  medcond_yn                     object
# dtypes: object(11)
# memory usage: 705.4+ MB

# %%
data.head(100)
# Out:
#    cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0     2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1     2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2     2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3     2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4     2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# ..           ...         ...         ...                        ...   ...
# 95    2020/11/16  2020/11/10         NaN  Laboratory-confirmed case  Male
# 96    2020/11/17  2020/11/10         NaN  Laboratory-confirmed case  Male
# 97    2020/11/10  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 98    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 99    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
#
#         age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0   10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1   10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2   10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3   10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4   10 - 19 Years           Black, Non-Hispanic       No       No       No
# ..            ...                           ...      ...      ...      ...
# 95  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 96  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
# 97  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 98  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 99  10 - 19 Years           Black, Non-Hispanic       No       No       No
#
#    medcond_yn
# 0          No
# 1          No
# 2          No
# 3     Missing
# 4         Yes
# ..        ...
# 95    Missing
# 96    Missing
# 97        Yes
# 98        Yes
# 99    Missing
#
# [100 rows x 11 columns]

# %%
df = data.head(10)

# %%
df
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 5    2020/11/17  2020/11/10  2020/11/08  Laboratory-confirmed case  Male
# 6    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 7    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 8    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 9    2020/11/17  2020/11/10         NaN  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 5  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
# 6  10 - 19 Years           Black, Non-Hispanic       No  Missing  Missing
# 7  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
# 8  10 - 19 Years           Black, Non-Hispanic  Unknown  Unknown       No
# 9  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
#
#   medcond_yn
# 0         No
# 1         No
# 2         No
# 3    Missing
# 4        Yes
# 5    Missing
# 6    Missing
# 7    Missing
# 8    Unknown
# 9    Missing

# %%
data.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.describe()
# Out:
#        cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# count             10          10           4                         10    10
# unique             5           1           3                          1     1
# top       2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# freq               3          10           2                         10    10
#
#             age_group Race and ethnicity (combined) hosp_yn   icu_yn death_yn  \
# count              10                            10      10       10       10
# unique              1                             1       3        3        2
# top     10 - 19 Years           Black, Non-Hispanic      No  Missing       No
# freq               10                            10       5        5        6
#
#        medcond_yn
# count          10
# unique          4
# top       Missing
# freq            5

# %%
df
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 5    2020/11/17  2020/11/10  2020/11/08  Laboratory-confirmed case  Male
# 6    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 7    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 8    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 9    2020/11/17  2020/11/10         NaN  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 5  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
# 6  10 - 19 Years           Black, Non-Hispanic       No  Missing  Missing
# 7  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
# 8  10 - 19 Years           Black, Non-Hispanic  Unknown  Unknown       No
# 9  10 - 19 Years           Black, Non-Hispanic  Missing  Missing  Missing
#
#   medcond_yn
# 0         No
# 1         No
# 2         No
# 3    Missing
# 4        Yes
# 5    Missing
# 6    Missing
# 7    Missing
# 8    Unknown
# 9    Missing

# %%
data.head(5)
# Out:
#   cdc_report_dt pos_spec_dt    onset_dt             current_status   sex  \
# 0    2020/11/10  2020/11/10         NaN  Laboratory-confirmed case  Male
# 1    2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
# 2    2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case  Male
# 3    2020/11/14  2020/11/10         NaN  Laboratory-confirmed case  Male
# 4    2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case  Male
#
#        age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  10 - 19 Years           Black, Non-Hispanic       No  Unknown       No
# 1  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 2  10 - 19 Years           Black, Non-Hispanic       No       No       No
# 3  10 - 19 Years           Black, Non-Hispanic  Missing  Missing       No
# 4  10 - 19 Years           Black, Non-Hispanic       No       No       No
#
#   medcond_yn
# 0         No
# 1         No
# 2         No
# 3    Missing
# 4        Yes

# %%
data.tail(5)
# Out:
#         cdc_report_dt pos_spec_dt onset_dt             current_status  \
# 8405074    2020/10/22         NaN      NaN              Probable Case
# 8405075    2020/10/25         NaN      NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN      NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN      NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN      NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# 8405074  Missing  30 - 39 Years                       Unknown       No
# 8405075  Missing  30 - 39 Years                       Unknown  Missing
# 8405076  Missing  30 - 39 Years                       Unknown  Missing
# 8405077  Missing  30 - 39 Years                       Unknown  Missing
# 8405078  Missing  30 - 39 Years                       Unknown       No
#
#           icu_yn death_yn medcond_yn
# 8405074  Unknown       No    Missing
# 8405075  Missing  Missing    Missing
# 8405076  Missing  Missing    Missing
# 8405077  Missing  Missing    Missing
# 8405078  Unknown       No    Missing
